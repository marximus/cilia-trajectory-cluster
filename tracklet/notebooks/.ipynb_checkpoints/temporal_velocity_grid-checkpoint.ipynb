# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tracks1 = np.load('sample_data/_ssd_Cohorts_CNMC_9036_rois_903614_roi_0_npy.npy')
tracks2 = np.load('sample_data/1001-8_roi_0_tracks.npy')

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="size", col_wrap=3)
g.axes[0].hist(tracks1['length'].flatten(), bins=25, normed=True)
# g = (g.map(plt.hist, "tip", bins=np.arange(0, 13), color="c").set_titles("{col_name} diners"))
# Out:
# <img src="data:image/png;base64,..." width="900">
# (array([ 0.03383797,  0.09728416,  0.20302781,  0.18610882,  0.29185247,
#          0.3130012 ,  0.31723095,  0.23263603,  0.21571705,  0.19033857,
#          0.13535187,  0.13112213,  0.11843289,  0.09305441,  0.07190568,
#          0.05921644,  0.06767594,  0.04652721,  0.00845949,  0.02114873,
#          0.00422975,  0.        ,  0.00845949,  0.00422975,  0.00845949]),
#  array([  5.30396128,   5.65369621,   6.00343115,   6.35316608,
#           6.70290102,   7.05263596,   7.40237089,   7.75210583,
#           8.10184076,   8.4515757 ,   8.80131063,   9.15104557,
#           9.50078051,   9.85051544,  10.20025038,  10.54998531,
#          10.89972025,  11.24945518,  11.59919012,  11.94892506,
#          12.29865999,  12.64839493,  12.99812986,  13.3478648 ,
#          13.69759974,  14.04733467]),
#  <a list of 25 Patch objects>)

# %%
g.axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d532a58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d587cc0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d5f91d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d64f518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d6b5da0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11d6b5dd8>], dtype=object)

# %%
# # end_frame only contains the frame each tracklet ends on. Expand it to contain
# # the frame number for each point.
# n_tracks, n_pts, _ = tracks['coords'].shape
# ts = np.mgrid[:n_tracks, :n_pts][1] - n_pts + tracks['frame_num'][:, None] + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-92070b829ea0> in <module>()
#       1 # end_frame only contains the frame each tracklet ends on. Expand it to contain
#       2 # the frame number for each point.
# ----> 3 n_tracks, n_pts, _ = tracks['coords'].shape
#       4 ts = np.mgrid[:n_tracks, :n_pts][1] - n_pts + tracks['frame_num'][:, None] + 1
#
# NameError: name 'tracks' is not defined

# %%
import sys
sys.path.append('/Users/maurice/PycharmProjects/updated_cilia')
from tracklet.tracklet import features as trackfeatures

vel = trackfeatures.velocity(tracks['coords'])
print(vel.shape)
vel_x = vel[:, :, 0]
vel_y = vel[:, :, 1]
mag = np.sqrt(vel_x**2 + vel_y**2)

# %%
x = []
y = []
for t in range(ts.max()):
    for m in mag[ts == t]:
        x.append(t)
        y.append(m)

# %%
plt.plot(x, y, '.', ms=2.0)
plt.xlabel('Time')
plt.ylabel('Velocity Magnitude')
# plt.show()
