# %%
# %matplotlib notebook

import os
import sys
sys.path.append("/Users/maurice/PycharmProjects/updated_cilia")

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

import cilia.utils.video as video_utils
from cilia.trajectory import distance
from scipy.spatial.distance import squareform
# plt.style.use('seaborn-notebook')

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
tracks = np.load('sample_data/1001-8_roi_0_tracks.npy')
tracks = tracks[np.random.choice(len(tracks), 25, True)]

# %%
# compute distances between trajectories
dist = distance.pdist(tracks['trajectory'])
squaredist = squareform(dist)

# %%
# remove mean and scale to unit variance
# std_scale = StandardScaler().fit(squaredist)
# squaredist_std = std_scale.transform(squaredist)
# print('mean after standardization: {}'.format(squaredist_std.mean(axis=0)))
# plot distance matrix
fig, ax = plt.subplots(1, 1, tight_layout=True)
sns.heatmap(squaredist, ax=ax, square=True, annot=True, annot_kws={'fontsize':6}, fmt='.1f')
# sns.heatmap(squaredist_std, ax=ax[1], square=True, annot=True, annot_kws={'fontsize':6}, fmt='.1f')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# remove mean and scale to unit variance
# std_scale = StandardScaler().fit(squaredist)
# squaredist_std = std_scale.transform(squaredist)
# print('mean after standardization: {}'.format(squaredist_std.mean(axis=0)))
# Out:
# mean after standardization: [ -2.30926389e-16  -2.39808173e-16   5.37347944e-16  -4.97379915e-16
#   -1.50990331e-16   6.21724894e-17  -1.12354570e-15   7.68274333e-16
#   -2.88657986e-16  -1.54987134e-15   2.48689958e-16   8.43769499e-16
#   -2.79776202e-16   1.28785871e-16   4.13002965e-16   1.07913678e-15
#   -1.24344979e-16  -5.01820807e-16  -8.66390293e-16   4.66293670e-16
#    7.10542736e-16  -5.10702591e-16   7.10542736e-17   1.68753900e-16
#   -1.42108547e-16]

# %%
# plot histogram of distances
fig, ax = plt.subplots(tight_layout=True)
sns.distplot(dist, axlabel="Distance", ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# trajectories with the smallest distance (ignoring diagonal)
np.fill_diagonal(squaredist, np.inf)
t1, t2 = np.unravel_index(squaredist.argmin(), squaredist.shape)
